# %%
import fitz

pdf_path = "/Users/jinchaoli/Desktop/Resume_rater/data/Jinchao_Li.pdf"

with fitz.open(pdf_path) as doc:
    print(f"Total pages: {doc.page_count}")

    for page_num, page in enumerate(doc, start=1):
        text = page.get_text()
        print(f"\n --- Page {page_num} ---\n{text[:600]}")
# Out:
# Total pages: 1
#
#  --- Page 1 ---
# Jinchao Li
#
# Phone: (+81) 07023338016     Email: 541681514lee@gmail.com
# Summary
# Innovative full stack developer proficient in JavaScript React and C# ASP.Net. Extensive experience
# on Restful API, CI/CD and Azure. Proven ability to work in agile teams, and to deliver tasks on time.
# Skills
# Languages:
#     Python, JavaScript, TypeScript
# Front end:
#     HTML5, CSS3, React, MUI, Bootstrap, Tailwind
# Back end:
#     C# ASP.Net, Restful API
# Tools & Cloud:     Git, Azure, AWS
#
# Intern Experience
# Maqro company, Sydney               04/2024 – 11/2024                 Full Stack Developer Intern
